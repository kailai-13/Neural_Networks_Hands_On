# %%
import tensorflow as tf 
import pandas as pd
import numpy as np 
from tensorflow import keras

# %%
df=pd.read_csv("Salary.csv")

# %%
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# 4                   20.0  200000.0
# ..                   ...       ...
# 370                  8.0   85000.0
# 371                 19.0  170000.0
# 372                  2.0   40000.0
# 373                  7.0   90000.0
# 374                 15.0  150000.0
#
# [375 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Job Title            373 non-null    object
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 17.7+ KB

# %%
df['Education Level'].value_counts()
# Out:
# Education Level
# Bachelor's    224
# Master's       98
# PhD            51
# Name: count, dtype: int64

# %%
df['Job Title'].value_counts()
# Out:
# Job Title
# Director of Marketing              12
# Director of Operations             11
# Senior Business Analyst            10
# Senior Marketing Analyst            9
# Senior Marketing Manager            9
#                                    ..
# Business Development Manager        1
# Customer Service Representative     1
# IT Manager                          1
# Digital Marketing Manager           1
# Junior Web Developer                1
# Name: count, Length: 174, dtype: int64

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      194
# Female    179
# Name: count, dtype: int64

# %%
df['Gender']=df['Gender'].apply(lambda x : 1 if x=='Female' else 0)
# Out:
# C:\Users\Kaila\AppData\Local\Temp\ipykernel_10852\1499105620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender']=df['Gender'].apply(lambda x : 1 if x=='Female' else 0)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 0    194
# 1    179
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Education Level']=le.fit_transform(df['Education Level'])
df['Job Title']=le.fit_transform(df['Job Title'])
# Out:
# C:\Users\Kaila\AppData\Local\Temp\ipykernel_10852\930720163.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Education Level']=le.fit_transform(df['Education Level'])
# C:\Users\Kaila\AppData\Local\Temp\ipykernel_10852\930720163.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Job Title']=le.fit_transform(df['Job Title'])

# %%
df['Education Level'].value_counts()
# Out:
# Education Level
# 0    224
# 1     98
# 2     51
# Name: count, dtype: int64

# %%
df['Job Title'].value_counts()
# Out:
# Job Title
# 29     12
# 30     11
# 110    10
# 131     9
# 134     9
#        ..
# 4       1
# 14      1
# 43      1
# 21      1
# 80      1
# Name: count, Length: 174, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 373 entries, 0 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    int64
#  2   Education Level      373 non-null    int32
#  3   Job Title            373 non-null    int32
#  4   Years of Experience  373 non-null    float64
#  5   Salary               373 non-null    float64
# dtypes: float64(3), int32(2), int64(1)
# memory usage: 17.5 KB

# %%
df.drop_duplicates(inplace=True)
# Out:
# C:\Users\Kaila\AppData\Local\Temp\ipykernel_10852\3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 324 entries, 0 to 371
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  324 non-null    float64
#  1   Gender               324 non-null    int64
#  2   Education Level      324 non-null    int32
#  3   Job Title            324 non-null    int32
#  4   Years of Experience  324 non-null    float64
#  5   Salary               324 non-null    float64
# dtypes: float64(3), int32(2), int64(1)
# memory usage: 15.2 KB

# %%
df.shape
# Out:
# (324, 6)

# %%
df.drop('Gender',axis=1,inplace=True)
# Out:
# C:\Users\Kaila\AppData\Local\Temp\ipykernel_10852\4287639956.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Gender',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Education Level', 'Job Title', 'Years of Experience', 'Salary'], dtype='object')

# %%
X=df.drop('Salary',axis=1)
y=df['Salary']

# %%
import seaborn as sns
sns.boxplot(X)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
sns.pairplot(df, hue='Salary')

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=100)
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(X_test,y_test)
# Out:
# 0.9323044872405126

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
lr.score(X_test,y_test)
# Out:
# 0.931144513781844

# %%
lr.coef_
# Out:
# array([ 2731.87233793, 14731.27294703,    28.76269735,  2892.10817971])

# %%
lr.intercept_
# Out:
# -41939.59405833506

# %%
from sklearn.metrics import classification_report
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([121201.32595425, 125317.30586739,  68543.23844332,  78205.75302195,
#         48866.06071304,  64858.69899043,  26874.94294215,  91326.8988277 ,
#         55968.69522753,  83332.03678505,  85255.52806477, 168250.57614164,
#         43722.54291767,  49740.47029862, 163946.07025937, 159578.44495553,
#        159705.72474694,  56042.64297727,  83817.97710759, 106127.92617143,
#         52961.3084915 , 146075.12575465,  24122.81103955,  53121.7721002 ,
#         95603.11458262,  52862.90782405,  83427.639687  ,  47612.84237196,
#        159865.96058872,  53581.9752578 ,  85428.10424887, 188692.11769836,
#         51137.72989337, 121045.17212519,  58186.92102588,  47054.01078   ,
#        182423.60140702,  59033.37959134, 142398.73329104,  38928.25950323,
#        179962.93368756,  85575.52717834, 157162.85094815,  93184.13381313,
#        152520.99549343, 165605.10323607, 105434.59590262,  61189.99798227,
#         47526.55427991, 162105.36896929,  89799.45033574, 139913.49622726,
#         86393.22304645,  45398.69858633,  56330.26995077, 151366.2942464 ,
#        143713.19780985,  42408.54588257,  61477.62495577,  83690.11340587,
#        120260.8878413 ,  88562.6543497 , 158173.73870842,  48233.28137135,
#         41775.18263056])

# %%
y_test
# Out:
# 132    100000.0
# 13     130000.0
# 94      75000.0
# 138     60000.0
# 91      40000.0
#          ...
# 288    130000.0
# 236    100000.0
# 176    140000.0
# 131     45000.0
# 212     40000.0
# Name: Salary, Length: 65, dtype: float64

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.931144513781844

# %%
import pickle 
with open('model.pkl','wb') as f:
    pickle.dump(lr,f)

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression(C=0.3)
lg.fit(X_train,y_train)
# Out:
# c:\Users\Kaila\.pyenv\pyenv-win\versions\3.10.0\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=0.3)

# %%
lg.score(X_test,y_test)
# Out:
# 0.2153846153846154

# %%
model=keras.models.Sequential([
    keras.layers.Dense(32,input_shape=(4,),activation='relu'),
    keras.layers.Dense(64,activation='relu'),
    keras.layers.Dense(1,activation='tanh')
])

# %%
model.compile(optimizer='adam',loss='MSE',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 0s 1ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 2/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 3/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 4/100
# 9/9 [==============================] - 0s 6ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 5/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549990400.0000 - accuracy: 0.0000e+00
# Epoch 6/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 7/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 8/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 9/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549990400.0000 - accuracy: 0.0000e+00
# Epoch 10/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 11/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 12/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 13/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 14/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 15/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549990400.0000 - accuracy: 0.0000e+00
# Epoch 16/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 17/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 18/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549990400.0000 - accuracy: 0.0000e+00
# Epoch 19/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 20/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 21/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 22/100
# 9/9 [==============================] - 0s 1ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 23/100
# 9/9 [==============================] - 0s 1ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 24/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 25/100
# 9/9 [==============================] - 0s 5ms/step - loss: 12549990400.0000 - accuracy: 0.0000e+00
# Epoch 26/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549990400.0000 - accuracy: 0.0000e+00
# Epoch 27/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 28/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 29/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 30/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 31/100
# 9/9 [==============================] - 0s 1ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 32/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 33/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 34/100
# 9/9 [==============================] - 0s 1ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 35/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 36/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 37/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 38/100
# 9/9 [==============================] - 0s 1ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 39/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 40/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 41/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 42/100
# 9/9 [==============================] - 0s 3ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 43/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 44/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 45/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 46/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 47/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549990400.0000 - accuracy: 0.0000e+00
# Epoch 48/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 49/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 50/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 51/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 52/100
# 9/9 [==============================] - 0s 3ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 53/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 54/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 55/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 56/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 57/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 58/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 59/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549990400.0000 - accuracy: 0.0000e+00
# Epoch 60/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 61/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 62/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 63/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 64/100
# 9/9 [==============================] - 0s 3ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 65/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 66/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 67/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 68/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 69/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 70/100
# 9/9 [==============================] - 0s 3ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 71/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 72/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 73/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 74/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 75/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 76/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 77/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549990400.0000 - accuracy: 0.0000e+00
# Epoch 78/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 79/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 80/100
# 9/9 [==============================] - 0s 7ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 81/100
# 9/9 [==============================] - 0s 3ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 82/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 83/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549990400.0000 - accuracy: 0.0000e+00
# Epoch 84/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 85/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 86/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 87/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 88/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 89/100
# 9/9 [==============================] - 0s 1ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 90/100
# 9/9 [==============================] - 0s 1ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 91/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 92/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 93/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 94/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 95/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 96/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549992448.0000 - accuracy: 0.0000e+00
# Epoch 97/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 98/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 99/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
# Epoch 100/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12549991424.0000 - accuracy: 0.0000e+00
